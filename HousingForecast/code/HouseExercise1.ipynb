# %%
'''数据处理'''
import pandas as pd
import numpy as np

train = pd.read_csv('../data/Etrain.csv')  # 导入训练集
test = pd.read_csv('../data/Etest.csv')  #导入测试集


#数值型和类别型分开处理
num_columns = []
cate_columns = []
for column in test.columns:
    if test.dtypes[column] != np.dtype('object'):
        num_columns.append(column)
    else:
        cate_columns.append(column)
print(num_columns)   #数值型数据的列名称
# Out:
# ['Id', 'OverallQual', 'YearBuilt', 'TotalBsmtSF', 'GrLivArea', 'FullBath', 'GarageCars']

# %%
print(cate_columns)   #类别型数据的列名称
# Out:
# ['SaleType']

# %%
label = train.pop('SalePrice')

# %%
#label2 = train.pop('OverallCond')

# %%
#缺失值填充
# 数值型用中值填充
for column in num_columns:
    train[column] = train[column].fillna(train[column].median())
    test[column] = test[column].fillna(test[column].median())

# # 类别型用最多的填充 
# for column in cate_columns:
#     train[column] = train[column].fillna(train[column].mode())
#     test[column] = test[column].fillna(test[column].mode())
    
# 类别型填充'NaN'
for column in cate_columns:
    train[column] = train[column].fillna('NaN')
    test[column] = test[column].fillna('NaN')
    
#类别型哑变量处理 将不能够定量处理的变量量化

data = pd.concat([train,test],axis=0) #训练集要和测试集放一起
for column in cate_columns:
    
    t = pd.get_dummies(data[column],prefix=column)
    train = pd.concat([train,t[:len(train)]],axis=1)
    train.drop(column,axis=1,inplace=True)
    
    test = pd.concat([test,t[len(train):]],axis=1)
    test.drop(column,axis=1,inplace=True)
# Out:
# d:\environment\python\install\lib\site-packages\ipykernel_launcher.py:19: FutureWarning: Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=False'.
#
# To retain the current behavior and silence the warning, pass 'sort=True'.

# %%
#回归
from sklearn.linear_model import Lasso,LinearRegression,Ridge,ElasticNet,TheilSenRegressor,HuberRegressor,RANSACRegressor
from sklearn.svm import SVR
from sklearn.tree import DecisionTreeRegressor,ExtraTreeRegressor
from sklearn.ensemble import AdaBoostRegressor,ExtraTreesRegressor,GradientBoostingRegressor,RandomForestRegressor
from xgboost import XGBRegressor
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error
import itertools

X_train, X_test, y_train, y_test = train_test_split(train, label, test_size=0.33, random_state=42)

regs = [
    ['Lasso',Lasso()],   #套索回归
    ['LinearRegression',LinearRegression()],  #线性回归
    ['Ridge',Ridge()],    #岭回归    
    ['TheilSenRegressor',TheilSenRegressor()],  #泰尔森回归
    ['RANSACRegressor',RANSACRegressor()],   #随机抽样一致性   
    ['DecisionTreeRegressor',DecisionTreeRegressor()],    #决策树回归
    ['RandomForestRegressor',RandomForestRegressor(n_estimators=150)],     #随机森林回归
    ['XGBRegressor',XGBRegressor(n_estimators=150)],
]

# %%
preds = []
for reg_name,reg in regs:
    print(reg_name)
    reg.fit(X_train,y_train)
    y_pred = reg.predict(X_test)
    if np.sum(y_pred<0) > 0:
        print('y_pred have',np.sum(y_pred<0),'negative values, we fill it with np.median(y_pred)')
        y_pred[y_pred<0] = np.median(y_pred)
    score = np.sqrt(mean_squared_error(np.log(y_test),np.log(y_pred)))
    preds.append([reg_name,y_pred])
    

final_results = []
for comb_length in range(1,len(regs)+1):
    print('Model Amount :',comb_length)
    results = []
    for comb in itertools.combinations(preds,comb_length):
        pred_sum = 0
        model_name = []
        for reg_name,pred in comb:
            pred_sum += pred
            model_name.append(reg_name)
        pred_sum /= comb_length
        model_name = '+'.join(model_name)
        score = np.sqrt(mean_squared_error(np.log(y_test),np.log(pred_sum)))
        results.append([model_name,score])
    results = sorted(results,key=lambda x:x[1])
    for model_name,score in results:
        print(model_name,score)
    print()
    final_results.append(results[0])
# Out:
# Lasso
# y_pred have 1 negative values, we fill it with np.median(y_pred)
# LinearRegression
# y_pred have 1 negative values, we fill it with np.median(y_pred)
# Ridge
# y_pred have 1 negative values, we fill it with np.median(y_pred)
# TheilSenRegressor
# RANSACRegressor
# DecisionTreeRegressor
# RandomForestRegressor
# XGBRegressor
# Model Amount : 1
# RandomForestRegressor 0.16358252197097084
# XGBRegressor 0.16652750584015594
# RANSACRegressor 0.1814725922097048
# Ridge 0.1975075594882399
# Lasso 0.21140993127755417
# LinearRegression 0.2124312121467681
# DecisionTreeRegressor 0.2171803779684804
# TheilSenRegressor 0.285784711987325
#
# Model Amount : 2
# RANSACRegressor+RandomForestRegressor 0.16186277104066768
# RandomForestRegressor+XGBRegressor 0.1619637886967034
# RANSACRegressor+XGBRegressor 0.16432054536057575
# Ridge+RandomForestRegressor 0.1667622380788972
# Lasso+RandomForestRegressor 0.16872318620269217
# LinearRegression+RandomForestRegressor 0.16882496261310453
# Ridge+XGBRegressor 0.1702778376469939
# RANSACRegressor+DecisionTreeRegressor 0.17280200123341588
# Lasso+XGBRegressor 0.17300710438522862
# LinearRegression+XGBRegressor 0.17314238528569162
# DecisionTreeRegressor+XGBRegressor 0.17455674017144235
# DecisionTreeRegressor+RandomForestRegressor 0.1759674731573577
# Ridge+RANSACRegressor 0.17907687977236458
# Ridge+DecisionTreeRegressor 0.17929946114119158
# Lasso+RANSACRegressor 0.18114585192463492
# Lasso+DecisionTreeRegressor 0.18115500695976738
# LinearRegression+RANSACRegressor 0.18125064727511145
# LinearRegression+DecisionTreeRegressor 0.18125533838242205
# Lasso+Ridge 0.20190684915275103
# LinearRegression+Ridge 0.20212162142338405
# Lasso+LinearRegression 0.2119114894113853
# TheilSenRegressor+RandomForestRegressor 0.21283917015101306
# TheilSenRegressor+XGBRegressor 0.21440166933122984
# TheilSenRegressor+DecisionTreeRegressor 0.21969682128261223
# TheilSenRegressor+RANSACRegressor 0.2207519081886369
# LinearRegression+TheilSenRegressor 0.23063323212959336
# Lasso+TheilSenRegressor 0.2306374324496672
# Ridge+TheilSenRegressor 0.23100914572099202
#
# Model Amount : 3
# RANSACRegressor+RandomForestRegressor+XGBRegressor 0.16039796522040947
# Ridge+RandomForestRegressor+XGBRegressor 0.16313944385122792
# Lasso+RandomForestRegressor+XGBRegressor 0.1642270225628131
# LinearRegression+RandomForestRegressor+XGBRegressor 0.16427965899710675
# RANSACRegressor+DecisionTreeRegressor+XGBRegressor 0.1644812920042123
# RANSACRegressor+DecisionTreeRegressor+RandomForestRegressor 0.1644870112534238
# Ridge+RANSACRegressor+RandomForestRegressor 0.165344506800048
# Lasso+RANSACRegressor+RandomForestRegressor 0.16624480232605035
# LinearRegression+RANSACRegressor+RandomForestRegressor 0.16628998622537142
# DecisionTreeRegressor+RandomForestRegressor+XGBRegressor 0.1667064891813524
# Ridge+RANSACRegressor+XGBRegressor 0.16747371427963578
# Ridge+DecisionTreeRegressor+RandomForestRegressor 0.1675156171473706
# Ridge+DecisionTreeRegressor+XGBRegressor 0.1679847997777926
# Lasso+DecisionTreeRegressor+RandomForestRegressor 0.1683173854787486
# LinearRegression+DecisionTreeRegressor+RandomForestRegressor 0.1683603674436413
# Lasso+RANSACRegressor+XGBRegressor 0.16861817134396098
# LinearRegression+RANSACRegressor+XGBRegressor 0.16867279736265245
# Ridge+RANSACRegressor+DecisionTreeRegressor 0.168914870233368
# Lasso+DecisionTreeRegressor+XGBRegressor 0.1690404504132928
# LinearRegression+DecisionTreeRegressor+XGBRegressor 0.16909321822475137
# Lasso+RANSACRegressor+DecisionTreeRegressor 0.16979629590491258
# LinearRegression+RANSACRegressor+DecisionTreeRegressor 0.1698422533590814
# Lasso+Ridge+RandomForestRegressor 0.17538143897912492
# LinearRegression+Ridge+RandomForestRegressor 0.17545074089644896
# Lasso+LinearRegression+RandomForestRegressor 0.17785816557133532
# Lasso+Ridge+XGBRegressor 0.17843558802845946
# LinearRegression+Ridge+XGBRegressor 0.17852000424457856
# Lasso+Ridge+DecisionTreeRegressor 0.1799766206160439
# LinearRegression+Ridge+DecisionTreeRegressor 0.18004694259855028
# Lasso+LinearRegression+XGBRegressor 0.18150347862718463
# Lasso+LinearRegression+DecisionTreeRegressor 0.18244340760784183
# Lasso+Ridge+RANSACRegressor 0.18534358396702125
# LinearRegression+Ridge+RANSACRegressor 0.18541397875094698
# Lasso+LinearRegression+RANSACRegressor 0.18786677406969485
# TheilSenRegressor+RandomForestRegressor+XGBRegressor 0.19068809991659008
# TheilSenRegressor+RANSACRegressor+RandomForestRegressor 0.19230009510357057
# TheilSenRegressor+DecisionTreeRegressor+XGBRegressor 0.19321244652688294
# TheilSenRegressor+DecisionTreeRegressor+RandomForestRegressor 0.19341318426772222
# TheilSenRegressor+RANSACRegressor+XGBRegressor 0.19351689419958523
# TheilSenRegressor+RANSACRegressor+DecisionTreeRegressor 0.1938518965782578
# Lasso+TheilSenRegressor+RandomForestRegressor 0.19738536070682428
# LinearRegression+TheilSenRegressor+RandomForestRegressor 0.19738591061299643
# Ridge+TheilSenRegressor+RandomForestRegressor 0.1975762692806684
# Lasso+TheilSenRegressor+XGBRegressor 0.19894774434334564
# LinearRegression+TheilSenRegressor+XGBRegressor 0.19894977842961
# Ridge+TheilSenRegressor+XGBRegressor 0.1991021371107551
# Lasso+TheilSenRegressor+DecisionTreeRegressor 0.1999267321682646
# LinearRegression+TheilSenRegressor+DecisionTreeRegressor 0.19992760523478895
# Ridge+TheilSenRegressor+DecisionTreeRegressor 0.20012097957734717
# Lasso+LinearRegression+Ridge 0.2044195656606697
# Lasso+TheilSenRegressor+RANSACRegressor 0.2050139940880167
# LinearRegression+TheilSenRegressor+RANSACRegressor 0.20501513364280685
# Ridge+TheilSenRegressor+RANSACRegressor 0.20517510918897974
# Lasso+Ridge+TheilSenRegressor 0.21419515789878096
# LinearRegression+Ridge+TheilSenRegressor 0.2141997162186981
# Lasso+LinearRegression+TheilSenRegressor 0.2142602056117312
#
# Model Amount : 4
# RANSACRegressor+DecisionTreeRegressor+RandomForestRegressor+XGBRegressor 0.16172029733434257
# Ridge+RANSACRegressor+RandomForestRegressor+XGBRegressor 0.1623795660450789
# Lasso+RANSACRegressor+RandomForestRegressor+XGBRegressor 0.16302020822938082
# LinearRegression+RANSACRegressor+RandomForestRegressor+XGBRegressor 0.16305087505757457
# Ridge+RANSACRegressor+DecisionTreeRegressor+RandomForestRegressor 0.16339155494614607
# Ridge+DecisionTreeRegressor+RandomForestRegressor+XGBRegressor 0.1636751553704855
# Lasso+RANSACRegressor+DecisionTreeRegressor+RandomForestRegressor 0.16389743627915934
# LinearRegression+RANSACRegressor+DecisionTreeRegressor+RandomForestRegressor 0.16392397422533245
# Ridge+RANSACRegressor+DecisionTreeRegressor+XGBRegressor 0.16397066773945018
# Lasso+DecisionTreeRegressor+RandomForestRegressor+XGBRegressor 0.16426392704382364
# LinearRegression+DecisionTreeRegressor+RandomForestRegressor+XGBRegressor
# d:\environment\python\install\lib\site-packages\xgboost\core.py:587: FutureWarning: Series.base is deprecated and will be removed in a future version
#   if getattr(data, 'base', None) is not None and \
#  0.1642934811411625
# Lasso+RANSACRegressor+DecisionTreeRegressor+XGBRegressor 0.16460230816373939
# LinearRegression+RANSACRegressor+DecisionTreeRegressor+XGBRegressor 0.1646334747226157
# Lasso+Ridge+RandomForestRegressor+XGBRegressor 0.16867490938873633
# LinearRegression+Ridge+RandomForestRegressor+XGBRegressor 0.16871763866560932
# Lasso+Ridge+DecisionTreeRegressor+RandomForestRegressor 0.1697886166037339
# LinearRegression+Ridge+DecisionTreeRegressor+RandomForestRegressor 0.16982580602834427
# Lasso+LinearRegression+RandomForestRegressor+XGBRegressor 0.1701008882362313
# Lasso+Ridge+DecisionTreeRegressor+XGBRegressor 0.17087126739878658
# LinearRegression+Ridge+DecisionTreeRegressor+XGBRegressor 0.17091457610230512
# Lasso+LinearRegression+DecisionTreeRegressor+RandomForestRegressor 0.17099129802555987
# Lasso+Ridge+RANSACRegressor+RandomForestRegressor 0.17153481934728843
# LinearRegression+Ridge+RANSACRegressor+RandomForestRegressor 0.17157266853706385
# Lasso+LinearRegression+DecisionTreeRegressor+XGBRegressor 0.1722903983839759
# Lasso+LinearRegression+RANSACRegressor+RandomForestRegressor 0.17278548249584835
# Lasso+Ridge+RANSACRegressor+DecisionTreeRegressor 0.17291953867177118
# LinearRegression+Ridge+RANSACRegressor+DecisionTreeRegressor 0.17295820478956453
# Lasso+Ridge+RANSACRegressor+XGBRegressor 0.17349243421113333
# LinearRegression+Ridge+RANSACRegressor+XGBRegressor 0.17353616665114877
# Lasso+LinearRegression+RANSACRegressor+DecisionTreeRegressor 0.17416973292199178
# Lasso+LinearRegression+RANSACRegressor+XGBRegressor 0.17495062008178613
# TheilSenRegressor+RANSACRegressor+RandomForestRegressor+XGBRegressor 0.18083005660045737
# TheilSenRegressor+RANSACRegressor+DecisionTreeRegressor+RandomForestRegressor 0.18114281236924237
# TheilSenRegressor+RANSACRegressor+DecisionTreeRegressor+XGBRegressor 0.18128395609973372
# TheilSenRegressor+DecisionTreeRegressor+RandomForestRegressor+XGBRegressor 0.18151454057612385
# Lasso+LinearRegression+Ridge+RandomForestRegressor 0.18155935923401678
# Lasso+LinearRegression+Ridge+DecisionTreeRegressor 0.18358669687518542
# Lasso+LinearRegression+Ridge+XGBRegressor 0.18419363060683228
# Lasso+TheilSenRegressor+RandomForestRegressor+XGBRegressor 0.18430486223930143
# LinearRegression+TheilSenRegressor+RandomForestRegressor+XGBRegressor 0.18430795973204095
# Ridge+TheilSenRegressor+RandomForestRegressor+XGBRegressor 0.1843809216499147
# Lasso+TheilSenRegressor+DecisionTreeRegressor+RandomForestRegressor 0.18494652126253397
# LinearRegression+TheilSenRegressor+DecisionTreeRegressor+RandomForestRegressor 0.18494865996451457
# Ridge+TheilSenRegressor+DecisionTreeRegressor+RandomForestRegressor 0.185056290977853
# Lasso+TheilSenRegressor+DecisionTreeRegressor+XGBRegressor 0.18534282650331033
# LinearRegression+TheilSenRegressor+DecisionTreeRegressor+XGBRegressor 0.18534613266285424
# Ridge+TheilSenRegressor+DecisionTreeRegressor+XGBRegressor 0.18542221332542708
# Lasso+TheilSenRegressor+RANSACRegressor+RandomForestRegressor 0.1868581065809814
# LinearRegression+TheilSenRegressor+RANSACRegressor+RandomForestRegressor 0.18686055334397547
# Ridge+TheilSenRegressor+RANSACRegressor+RandomForestRegressor 0.18694595510630224
# Lasso+TheilSenRegressor+RANSACRegressor+DecisionTreeRegressor 0.1872246508331977
# LinearRegression+TheilSenRegressor+RANSACRegressor+DecisionTreeRegressor 0.1872273292520414
# Ridge+TheilSenRegressor+RANSACRegressor+DecisionTreeRegressor 0.18731635497294025
# Lasso+TheilSenRegressor+RANSACRegressor+XGBRegressor 0.18805888932818565
# LinearRegression+TheilSenRegressor+RANSACRegressor+XGBRegressor 0.188062442833387
# Ridge+TheilSenRegressor+RANSACRegressor+XGBRegressor 0.18811799989801936
# Lasso+LinearRegression+Ridge+RANSACRegressor 0.18973742108145278
# Lasso+Ridge+TheilSenRegressor+RandomForestRegressor 0.19243779513840129
# LinearRegression+Ridge+TheilSenRegressor+RandomForestRegressor 0.19244295206620346
# Lasso+LinearRegression+TheilSenRegressor+RandomForestRegressor 0.19252296505642344
# Lasso+Ridge+TheilSenRegressor+DecisionTreeRegressor 0.1933985710555598
# LinearRegression+Ridge+TheilSenRegressor+DecisionTreeRegressor 0.19340397859869463
# Lasso+LinearRegression+TheilSenRegressor+DecisionTreeRegressor 0.19347985173896987
# Lasso+Ridge+TheilSenRegressor+XGBRegressor 0.19380173211563329
# LinearRegression+Ridge+TheilSenRegressor+XGBRegressor 0.1938081884337402
# Lasso+LinearRegression+TheilSenRegressor+XGBRegressor 0.19392664000189985
# Lasso+Ridge+TheilSenRegressor+RANSACRegressor 0.1992090556806942
# LinearRegression+Ridge+TheilSenRegressor+RANSACRegressor 0.19921453763691882
# Lasso+LinearRegression+TheilSenRegressor+RANSACRegressor 0.19931138870396156
# Lasso+LinearRegression+Ridge+TheilSenRegressor 0.20732619414753992
#
# Model Amount : 5
# Ridge+RANSACRegressor+DecisionTreeRegressor+RandomForestRegressor+XGBRegressor 0.16141486603971528
# Lasso+RANSACRegressor+DecisionTreeRegressor+RandomForestRegressor+XGBRegressor 0.1618256282739041
# LinearRegression+RANSACRegressor+DecisionTreeRegressor+RandomForestRegressor+XGBRegressor 0.16184604463500377
# Lasso+Ridge+DecisionTreeRegressor+RandomForestRegressor+XGBRegressor 0.16589618412205165
# LinearRegression+Ridge+DecisionTreeRegressor+RandomForestRegressor+XGBRegressor 0.16592319547572099
# Lasso+Ridge+RANSACRegressor+DecisionTreeRegressor+RandomForestRegressor 0.16664988669167813
# LinearRegression+Ridge+RANSACRegressor+DecisionTreeRegressor+RandomForestRegressor 0.1666745906222048
# Lasso+LinearRegression+DecisionTreeRegressor+RandomForestRegressor+XGBRegressor 0.1667391758156667
# Lasso+Ridge+RANSACRegressor+RandomForestRegressor+XGBRegressor 0.1668839325929024
# LinearRegression+Ridge+RANSACRegressor+RandomForestRegressor+XGBRegressor 0.16691141128044956
# Lasso+LinearRegression+RANSACRegressor+DecisionTreeRegressor+RandomForestRegressor 0.16741160639837988
# Lasso+Ridge+RANSACRegressor+DecisionTreeRegressor+XGBRegressor 0.16751796188212875
# LinearRegression+Ridge+RANSACRegressor+DecisionTreeRegressor+XGBRegressor 0.16754593672309742
# Lasso+LinearRegression+RANSACRegressor+RandomForestRegressor+XGBRegressor 0.16775734536160414
# Lasso+LinearRegression+RANSACRegressor+DecisionTreeRegressor+XGBRegressor 0.16839036655710332
# Lasso+LinearRegression+Ridge+DecisionTreeRegressor+RandomForestRegressor 0.17350174616837744
# Lasso+LinearRegression+Ridge+RandomForestRegressor+XGBRegressor 0.17369228494028197
# TheilSenRegressor+RANSACRegressor+DecisionTreeRegressor+RandomForestRegressor+XGBRegressor 0.1745646793010836
# Lasso+LinearRegression+Ridge+DecisionTreeRegressor+XGBRegressor 0.1747555162702954
# Lasso+LinearRegression+Ridge+RANSACRegressor+RandomForestRegressor 0.1765748605472162
# Lasso+LinearRegression+Ridge+RANSACRegressor+DecisionTreeRegressor 0.17708268040209676
# Lasso+TheilSenRegressor+DecisionTreeRegressor+RandomForestRegressor+XGBRegressor 0.17736038816371177
# LinearRegression+TheilSenRegressor+DecisionTreeRegressor+RandomForestRegressor+XGBRegressor 0.177363806077671
# Ridge+TheilSenRegressor+DecisionTreeRegressor+RandomForestRegressor+XGBRegressor 0.17740035044631525
# Lasso+TheilSenRegressor+RANSACRegressor+DecisionTreeRegressor+RandomForestRegressor 0.17805052271223196
# LinearRegression+TheilSenRegressor+RANSACRegressor+DecisionTreeRegressor+RandomForestRegressor 0.17805344321098265
# Ridge+TheilSenRegressor+RANSACRegressor+DecisionTreeRegressor+RandomForestRegressor 0.17810238485937313
# Lasso+LinearRegression+Ridge+RANSACRegressor+XGBRegressor 0.17834906602727568
# Lasso+TheilSenRegressor+RANSACRegressor+DecisionTreeRegressor+XGBRegressor 0.17849020738667198
# LinearRegression+TheilSenRegressor+RANSACRegressor+DecisionTreeRegressor+XGBRegressor 0.17849402221522567
# Ridge+TheilSenRegressor+RANSACRegressor+DecisionTreeRegressor+XGBRegressor 0.17851807381561643
# Lasso+TheilSenRegressor+RANSACRegressor+RandomForestRegressor+XGBRegressor 0.17853460486980585
# LinearRegression+TheilSenRegressor+RANSACRegressor+RandomForestRegressor+XGBRegressor 0.17853824706363428
# Ridge+TheilSenRegressor+RANSACRegressor+RandomForestRegressor+XGBRegressor 0.17855967062174874
# Lasso+Ridge+TheilSenRegressor+DecisionTreeRegressor+RandomForestRegressor 0.1823192062791713
# LinearRegression+Ridge+TheilSenRegressor+DecisionTreeRegressor+RandomForestRegressor 0.18232420778583186
# Lasso+LinearRegression+TheilSenRegressor+DecisionTreeRegressor+RandomForestRegressor 0.18240034402873523
# Lasso+Ridge+TheilSenRegressor+RandomForestRegressor+XGBRegressor 0.1825447812098104
# LinearRegression+Ridge+TheilSenRegressor+RandomForestRegressor+XGBRegressor 0.18255060696244976
# Lasso+LinearRegression+TheilSenRegressor+RandomForestRegressor+XGBRegressor 0.18265963270199406
# Lasso+Ridge+TheilSenRegressor+DecisionTreeRegressor+XGBRegressor 0.18290417713522059
# LinearRegression+Ridge+TheilSenRegressor+DecisionTreeRegressor+XGBRegressor 0.18291018347391336
# Lasso+LinearRegression+TheilSenRegressor+DecisionTreeRegressor+XGBRegressor 0.18301635832345506
# Lasso+Ridge+TheilSenRegressor+RANSACRegressor+DecisionTreeRegressor 0.18522356936725615
# LinearRegression+Ridge+TheilSenRegressor+RANSACRegressor+DecisionTreeRegressor 0.18522894647898683
# Lasso+LinearRegression+TheilSenRegressor+RANSACRegressor+DecisionTreeRegressor 0.18531817269596532
# Lasso+Ridge+TheilSenRegressor+RANSACRegressor+RandomForestRegressor 0.18534678204006702
# LinearRegression+Ridge+TheilSenRegressor+RANSACRegressor+RandomForestRegressor 0.1853519554504864
# Lasso+LinearRegression+TheilSenRegressor+RANSACRegressor+RandomForestRegressor 0.18544389548125892
# Lasso+Ridge+TheilSenRegressor+RANSACRegressor+XGBRegressor 0.18643509465995695
# LinearRegression+Ridge+TheilSenRegressor+RANSACRegressor+XGBRegressor 0.18644122723198336
# Lasso+LinearRegression+TheilSenRegressor+RANSACRegressor+XGBRegressor 0.1865615339249953
# Lasso+LinearRegression+Ridge+TheilSenRegressor+RandomForestRegressor 0.19081270952714482
# Lasso+LinearRegression+Ridge+TheilSenRegressor+DecisionTreeRegressor 0.19107780520558765
# Lasso+LinearRegression+Ridge+TheilSenRegressor+XGBRegressor 0.19202995823524496
# Lasso+LinearRegression+Ridge+TheilSenRegressor+RANSACRegressor 0.1967904417846562
#
# Model Amount : 6
# Lasso+Ridge+RANSACRegressor+DecisionTreeRegressor+RandomForestRegressor+XGBRegressor 0.1640318356875474
# LinearRegression+Ridge+RANSACRegressor+DecisionTreeRegressor+RandomForestRegressor+XGBRegressor 0.164051337178273
# Lasso+LinearRegression+RANSACRegressor+DecisionTreeRegressor+RandomForestRegressor+XGBRegressor 0.16461968225778534
# Lasso+LinearRegression+Ridge+DecisionTreeRegressor+RandomForestRegressor+XGBRegressor 0.16909650009517133
# Lasso+LinearRegression+Ridge+RANSACRegressor+DecisionTreeRegressor+RandomForestRegressor 0.17031491101493051
# Lasso+LinearRegression+Ridge+RANSACRegressor+RandomForestRegressor+XGBRegressor 0.17109527351847323
# Lasso+LinearRegression+Ridge+RANSACRegressor+DecisionTreeRegressor+XGBRegressor 0.1712823265606873
# Lasso+TheilSenRegressor+RANSACRegressor+DecisionTreeRegressor+RandomForestRegressor+XGBRegressor 0.17306455294549877
# LinearRegression+TheilSenRegressor+RANSACRegressor+DecisionTreeRegressor+RandomForestRegressor+XGBRegressor 0.17306814009343405
# Ridge+TheilSenRegressor+RANSACRegressor+DecisionTreeRegressor+RandomForestRegressor+XGBRegressor 0.17307376081904177
# Lasso+Ridge+TheilSenRegressor+DecisionTreeRegressor+RandomForestRegressor+XGBRegressor 0.17632236910776275
# LinearRegression+Ridge+TheilSenRegressor+DecisionTreeRegressor+RandomForestRegressor+XGBRegressor 0.17632764820330932
# Lasso+LinearRegression+TheilSenRegressor+DecisionTreeRegressor+RandomForestRegressor+XGBRegressor 0.17642230389436767
# Lasso+Ridge+TheilSenRegressor+RANSACRegressor+DecisionTreeRegressor+RandomForestRegressor 0.17754073244128774
# LinearRegression+Ridge+TheilSenRegressor+RANSACRegressor+DecisionTreeRegressor+RandomForestRegressor 0.17754553785262575
# Lasso+LinearRegression+TheilSenRegressor+RANSACRegressor+DecisionTreeRegressor+RandomForestRegressor 0.1776266081761694
# Lasso+Ridge+TheilSenRegressor+RANSACRegressor+DecisionTreeRegressor+XGBRegressor 0.17808254953547234
# LinearRegression+Ridge+TheilSenRegressor+RANSACRegressor+DecisionTreeRegressor+XGBRegressor 0.17808812635343954
# Lasso+LinearRegression+TheilSenRegressor+RANSACRegressor+DecisionTreeRegressor+XGBRegressor 0.17819219126411323
# Lasso+Ridge+TheilSenRegressor+RANSACRegressor+RandomForestRegressor+XGBRegressor 0.1783556051425102
# LinearRegression+Ridge+TheilSenRegressor+RANSACRegressor+RandomForestRegressor+XGBRegressor 0.17836102586666633
# Lasso+LinearRegression+TheilSenRegressor+RANSACRegressor+RandomForestRegressor+XGBRegressor 0.17846697360978284
# Lasso+LinearRegression+Ridge+TheilSenRegressor+DecisionTreeRegressor+RandomForestRegressor 0.18186021353670945
# Lasso+LinearRegression+Ridge+TheilSenRegressor+RandomForestRegressor+XGBRegressor 0.18251079829852493
# Lasso+LinearRegression+Ridge+TheilSenRegressor+DecisionTreeRegressor+XGBRegressor 0.18252639933565534
# Lasso+LinearRegression+Ridge+TheilSenRegressor+RANSACRegressor+DecisionTreeRegressor 0.18494398117564295
# Lasso+LinearRegression+Ridge+TheilSenRegressor+RANSACRegressor+RandomForestRegressor 0.1852904237504849
# Lasso+LinearRegression+Ridge+TheilSenRegressor+RANSACRegressor+XGBRegressor 0.18629281700564077
#
# Model Amount : 7
# Lasso+LinearRegression+Ridge+RANSACRegressor+DecisionTreeRegressor+RandomForestRegressor+XGBRegressor 0.16711504223464746
# Lasso+Ridge+TheilSenRegressor+RANSACRegressor+DecisionTreeRegressor+RandomForestRegressor+XGBRegressor 0.173175427780768
# LinearRegression+Ridge+TheilSenRegressor+RANSACRegressor+DecisionTreeRegressor+RandomForestRegressor+XGBRegressor 0.17318032359361193
# Lasso+LinearRegression+TheilSenRegressor+RANSACRegressor+DecisionTreeRegressor+RandomForestRegressor+XGBRegressor 0.17327169697947925
# Lasso+LinearRegression+Ridge+TheilSenRegressor+DecisionTreeRegressor+RandomForestRegressor+XGBRegressor 0.1766192707212916
# Lasso+LinearRegression+Ridge+TheilSenRegressor+RANSACRegressor+DecisionTreeRegressor+RandomForestRegressor 0.1780800500002081
# Lasso+LinearRegression+Ridge+TheilSenRegressor+RANSACRegressor+DecisionTreeRegressor+XGBRegressor 0.17867313917477162
# Lasso+LinearRegression+Ridge+TheilSenRegressor+RANSACRegressor+RandomForestRegressor+XGBRegressor 0.1790575929892423
#
# Model Amount : 8
# Lasso+LinearRegression+Ridge+TheilSenRegressor+RANSACRegressor+DecisionTreeRegressor+RandomForestRegressor+XGBRegressor 0.17402839475610643

# %%
final_results = sorted(final_results,key=lambda x:x[1])
for model_name,score in final_results:
    print(model_name,score)
# Out:
# RANSACRegressor+RandomForestRegressor+XGBRegressor 0.16039796522040947
# Ridge+RANSACRegressor+DecisionTreeRegressor+RandomForestRegressor+XGBRegressor 0.16141486603971528
# RANSACRegressor+DecisionTreeRegressor+RandomForestRegressor+XGBRegressor 0.16172029733434257
# RANSACRegressor+RandomForestRegressor 0.16186277104066768
# RandomForestRegressor 0.16358252197097084
# Lasso+Ridge+RANSACRegressor+DecisionTreeRegressor+RandomForestRegressor+XGBRegressor 0.1640318356875474
# Lasso+LinearRegression+Ridge+RANSACRegressor+DecisionTreeRegressor+RandomForestRegressor+XGBRegressor 0.16711504223464746
# Lasso+LinearRegression+Ridge+TheilSenRegressor+RANSACRegressor+DecisionTreeRegressor+RandomForestRegressor+XGBRegressor 0.17402839475610643

# %%
#最终输出
[b for b in zip(itertools.count(),[a[0] for a in regs])]

pred = np.mean(list(map(lambda x:regs[x][1].predict(test),[0,5,6])),axis=0)

sub = pd.DataFrame({'Id':test['Id'],'SalePrice':pred})
sub.to_csv('D:/Desktop/predict.csv',index=None)
